# %% [markdown]
# # Determine image dimentions, openCV
#
# ## Code for detyermining proper scaled size for images using openCV.

# %%
# !conda activate DS807

# %%
import cv2
from IPython.display import Image
import matplotlib.pyplot as plt
import os

os.chdir("D:\DS807_exam\Kaggle_data\DIDA_12000_String_Digit_Images\DIDA_1")
os.getcwd()
# Out:
# 'D:\\DS807_exam\\Kaggle_data\\DIDA_12000_String_Digit_Images\\DIDA_1'

# %% [markdown]
# ### Import one of the largest images

# %%
img = cv2.imread("7005.jpg",0)
print("Image size is ", img.shape)
# Out:
# Image size is  (341, 463)

# %%
Image('7005.jpg')

# %%
plt.imshow(img,cmap='gray')

# %% [markdown]
# #### Downscale the image

# %%
dim = (106, 56) #Define dimensions for dsize

# Resize background image to sae size as logo image
img_scale = cv2.resize(img, dsize = dim, interpolation=cv2.INTER_AREA) #Interpolation, different methods to call in documentation.
plt.imshow(img_scale, cmap = 'gray')

# %% [markdown]
# ### Import one of the smallest images

# %%
img = cv2.imread("192.jpg",0)
print("Image size is ", img.shape)
# Out:
# Image size is  (57, 85)

# %%
Image('192.jpg')

# %%
plt.imshow(img,cmap='gray')

# %% [markdown]
# #### Upscale the image

# %%
dim = (106, 56) #Define dimensions for dsize

# Resize background image to sae size as logo image
img_scale = cv2.resize(img, dsize = dim, interpolation=cv2.INTER_AREA) #Interpolation, different methods to call in documentation.
plt.imshow(img_scale, cmap = 'gray')

# %% [markdown]
# ### Import a mid range image

# %%
img = cv2.imread("1486.jpg",0)
print("Image size is ", img.shape)
# Out:
# Image size is  (198, 384)

# %%
Image('1486.jpg')

# %%
plt.imshow(img,cmap='gray')

# %% [markdown]
# #### Upscale the image

# %%
dim = (106, 56) #Define dimensions for dsize

# Resize background image to sae size as logo image
img_scale = cv2.resize(img, dsize = dim, interpolation=cv2.INTER_AREA) #Interpolation, different methods to call in documentation.
plt.imshow(img_scale, cmap = 'gray')
