# %%
# !conda activate DS807

# %%
import data_loader as dl
# Out:
# Traceback (most recent call last):
#
#   File "D:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "C:\Users\jakob\AppData\Local\Temp/ipykernel_26112/4095178130.py", line 1, in <module>
#     import data_loader as dl
#
#   File "D:\DS807_exam\Anvendt_ML_Eskamens_project\data_loader.py", line 38
#     <<<<<<< HEAD
#     ^
# IndentationError: expected an indented block

# %%
df = dl.load_1d_grays()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26112/3959162349.py in <module>
#       2 path_images = 'C:\\Users\\oeste\\OneDrive\\Uni\\DS_3_semester\\Anvendt_ML\\DIDA_12000_String_Digit_Images\\DIDA_1'
#       3
# ----> 4 df = dl.load_1d_grays()
#
# NameError: name 'dl' is not defined

# %%
df
# Out:
#        index string CC  D  Y  \
# 0          1   1836  0  3  6
# 1          2   1836  0  3  6
# 2          3   1840  0  4  0
# 3          4   1840  0  4  0
# 4          5   1823  0  2  3
# ...      ...    ... .. .. ..
# 11995  11996   1808  0  0  8
# 11996  11997   1809  0  0  9
# 11997  11998   1840  0  4  0
# 11998  11999   1840  0  4  0
# 11999  12000   1810  0  1  0
#
#                                               gray_value   filename
# 0      [166.0, 167.0, 166.0, 162.0, 164.0, 164.0, 166...      1.jpg
# 1      [169.0, 168.0, 169.0, 170.0, 166.0, 164.0, 164...      2.jpg
# 2      [167.0, 169.0, 169.0, 166.0, 165.0, 168.0, 169...      3.jpg
# 3      [167.0, 165.0, 165.0, 165.0, 163.0, 161.0, 162...      4.jpg
# 4      [62.0, 45.0, 45.0, 37.0, 40.0, 33.0, 46.0, 64....      5.jpg
# ...                                                  ...        ...
# 11995  [88.0, 62.0, 60.0, 68.0, 61.0, 101.0, 132.0, 1...  11996.jpg
# ...
